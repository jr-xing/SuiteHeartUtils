# %%
# %load_ext autoreload
# %autoreload 2
# %cd ..
from pathlib import Path
from utils.loadmat import loadmat
from utils.check_dict import check_dict
# Out:
# c:\Users\remus\Documents\Development\SuiteHeartUtils

# %%
input_mat_fname = 'debug_data/0007/input.mat'
input_mat = loadmat(input_mat_fname)

# %%
check_dict(input_mat)
# Out:
# __header__                               b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Fri Jul 29 05:22:50 2022'
# __version__                              1.0
# __globals__                              []
# input                                    (48, 48, 26)

# %%
import matplotlib.pyplot as plt
plt.imshow(input_mat['input'][...,10], cmap='gray')

# %%
mat_exported = loadmat(r'C:\Users\remus\Documents\Development\SuiteHeartUtils\analyzed_files\trufi_cine_sa_p2_8.mat_0\input.mat')
plt.imshow(mat_exported['input'][...,10], cmap='gray')
